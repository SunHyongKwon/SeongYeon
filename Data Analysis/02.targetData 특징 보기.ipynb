# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import platform
import warnings

# %%
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

warnings.filterwarnings('ignore')

# %% [markdown]
# ### target 데이터 특징 보기

# %%
target=pd.read_csv('./Data/rice_target.csv')
target[(target['년도'] == 1998) & (target['월'] == 1)]
# Out:
#             날짜    년도  월    소비량
# 2   1998-01-01  1998  1  285.7
# 11  1998-01-01  1998  1  270.3

# %%
target_sub = pd.DataFrame(
    {
        'index':target.index,
        'consumption':target['소비량']
    }
)

# %%
plt.style.use('ggplot')

target_sub.plot(
    kind='scatter',
    x='index',
    y='consumption',
    s = 50,
    alpha = 0.3,
    figsize=(10,5),
    marker = 'o'
)

plt.title('1997년도 부터 2022년까지 쌀 소비량(1인당)')
plt.ylabel('소비량(g)')

plt.savefig('./Plot/쌀소비량산점도.jpg')

plt.show()
