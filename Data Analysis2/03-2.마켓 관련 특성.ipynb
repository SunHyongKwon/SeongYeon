# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split , cross_validate
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression , Lasso , Ridge , ElasticNet , QuantileRegressor

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 레스토랑 관련

# %%
df = pd.read_csv('./Data/global_cost.csv')
df.head()
# Out:
#        city      country    x1     x2    x3    x4    x5    x6    x7    x8  \
# 0     Delhi        India  4.90  22.04  4.28  1.84  3.67  1.78  0.48  0.19
# 1  Shanghai        China  5.59  40.51  5.59  1.12  4.19  3.96  0.52  0.32
# 2   Jakarta    Indonesia  2.54  22.25  3.50  2.02  3.18  2.19  0.59  0.27
# 3    Manila  Philippines  3.54  27.40  3.54  1.24  1.90  2.91  0.93  0.51
# 4     Seoul  South Korea  7.16  52.77  6.03  3.02  4.52  3.86  1.46  0.78
#
#    ...     x47      x48     x49      x50      x51       x52       x53  \
# 0  ...   36.26   223.87  133.38   596.16   325.82   2619.46   1068.90
# 1  ...  121.19  1080.07  564.30  2972.57  1532.23  17333.09   9174.88
# 2  ...   80.32   482.85  270.15  1117.69   584.37   2694.05   1269.44
# 3  ...   61.82   559.52  281.78  1754.40   684.81   3536.04   2596.44
# 4  ...  108.30   809.83  583.60  2621.05  1683.74  21847.94  10832.90
#
#        x54   x55  data_quality
# 0   586.35  7.96             1
# 1  1382.83  5.01             1
# ...

# %%
columns = ['x1','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20','x21','x22','x23','x24','x25','x26','x26']

res=df[columns]

# %%
res.corr()
# Out:
#            x1        x9       x10       x11       x12       x13       x14  \
# x1   1.000000  0.209656  0.663892  0.576710  0.760824  0.482747  0.771732
# x9   0.209656  1.000000  0.339184  0.274740  0.380777  0.370488  0.276011
# x10  0.663892  0.339184  1.000000  0.688767  0.710416  0.512867  0.732313
# x11  0.576710  0.274740  0.688767  1.000000  0.583856  0.429146  0.661177
# x12  0.760824  0.380777  0.710416  0.583856  1.000000  0.517071  0.808177
# x13  0.482747  0.370488  0.512867  0.429146  0.517071  1.000000  0.591435
# x14  0.771732  0.276011  0.732313  0.661177  0.808177  0.591435  1.000000
# x15  0.594808  0.361623  0.541965  0.461528  0.631794  0.599956  0.717953
# x16  0.451369  0.324645  0.655307  0.644847  0.488975  0.417082  0.540328
# x17  0.425751  0.398210  0.388095  0.491120  0.556675  0.424939  0.484306
# x18  0.572922  0.348663  0.674109  0.716667  0.588825  0.481582  0.621020
# x19  0.643239  0.259118  0.671611  0.693367  0.640685  0.448835  0.653179
# ...

# %% [markdown]
# #### 레스토랑 관련 카테고리로만 예측률 확인하기

# %%
import Module.default as dft

# %%
data = res[res.columns.difference(['x1'])].to_numpy()
target = res['x1'].to_numpy()
columns = res[res.columns.difference(['x1'])].columns

# %%
dft.importance(data,target,columns)
# Out:
# column 이름 : x10
# x10 feature	importaces	- dt : 0.023159281411416884,	rf : 0.03145199863011843
# x10 permutation	importaces	- dt : 0.20922975164911817,	rf : 0.041431326615989694
# x10 별 차이			- dt : -0.1860704702377013,	rf : -0.009979327985871263
# ----------------------------------------------------------------------------------------------------
# column 이름 : x11
# x11 feature	importaces	- dt : 0.0123694087651704,	rf : 0.014336113209901243
# x11 permutation	importaces	- dt : 0.05128151573319016,	rf : 0.015413483615365342
# x11 별 차이			- dt : -0.03891210696801976,	rf : -0.0010773704054640992
# ----------------------------------------------------------------------------------------------------
# column 이름 : x12
# x12 feature	importaces	- dt : 0.024300356687400777,	rf : 0.07108101297979902
# x12 permutation	importaces	- dt : 0.21012009964029082,	rf : 0.13823197224743028
# x12 별 차이			- dt : -0.18581974295289005,	rf : -0.06715095926763126
# ...

# %% [markdown]
# ### 차이를 보았을 때 레스토랑 데이터는 점심 식사 맞추는데 큰 영향이 없어 보인다.
