# %%
import numpy as np
import pandas as pd

# %%
df_pasgnr=pd.read_csv('./Data/TPSS_STA_ROUTE_INFO_H_PASNGR.csv')
df_
# Out:
#         STDR_DE   ROUTE_ID      STTN_ID     CNT  CNT_00H  CNT_01H  CNT_02H  \
# 0      20230204  100100038  105000010.0   104.0      2.0      NaN      NaN
# 1      20230204  100100038  105000234.0    15.0      1.0      NaN      NaN
# 2      20230204  100100038  106000429.0    50.0      2.0      1.0      NaN
# 3      20230204  100100038  106000432.0   270.0      6.0      2.0      1.0
# 4      20230204  100100038  221000073.0     1.0      NaN      NaN      NaN
# ...         ...        ...          ...     ...      ...      ...      ...
# 80781  20230204          0       1013.0  8712.0      3.0      NaN      NaN
# 80782  20230204          0       1017.0  4286.0      NaN      NaN      NaN
# 80783  20230204          0       1020.0  3129.0      NaN      NaN      NaN
# 80784  20230204          0       1025.0  3799.0      NaN      NaN      NaN
# 80785  20230204          0       1030.0  5309.0      1.0      NaN      NaN
#
# ...
