# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
import warnings

# seaborn 사용하기
import seaborn as sns

plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('./Data/second_target.csv')
data.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명  시군구코드 시군구명    행정동_코드 행정동_코드_명  \
# 0     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 1     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 2     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 3     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 4     2021         1        A       골목상권  11110  종로구  11110600      가회동
#
#      상권_코드 상권_코드_명  ... 시간대_건수~24_매출_건수 남성_매출_건수  여성_매출_건수  연령대_10_매출_건수  \
# 0  1000001     계동길  ...             204     6283      4828           402
# 1  1000001     계동길  ...              11      825      1041           243
# 2  1000001     계동길  ...             136      519       635             0
# 3  1000001     계동길  ...              66     1778      2175            31
# 4  1000001     계동길  ...             676     7523      9187           208
#
#    연령대_20_매출_건수  연령대_30_매출_건수  연령대_40_매출_건수  연령대_50_매출_건수  연령대_60_이상_매출_건수  \
# 0          2286          2963          2673          1717             1068
# 1           629           307           322           269               97
# 2           185           339           242           279              112
# 3          1505          1155           439           566              256
# 4          2471          4577          3857          2990             2609
#
#    점포수
# 0   16
# 1    1
# 2    2
# 3    3
# 4    4
#
# [5 rows x 84 columns]

# %%
target=data.iloc[:,:13]
feature=data[['시간대_06~11_매출_비율','연령대_20_매출_비율','점포수']]
feature.head()

target=pd.concat([target,feature],axis=1)

food=target[target['서비스_업종_코드_명'].isin(
       ['한식음식점', '중식음식점', '일식음식점', '양식음식점',
          '패스트푸드점', '분식전문점',
          '치킨전문점','제과점','호프-간이주점','커피-음료'])]

food.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명  시군구코드 시군구명    행정동_코드 행정동_코드_명  \
# 0     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 1     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 2     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 3     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 4     2021         1        A       골목상권  11110  종로구  11110600      가회동
#
#      상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  분기당_매출_금액  시간대_06~11_매출_비율  \
# 0  1000001     계동길  CS100001       한식음식점  316763168                2
# 1  1000001     계동길  CS100002       중식음식점   39791852                0
# 2  1000001     계동길  CS100003       일식음식점   60325474                0
# 3  1000001     계동길  CS100004       양식음식점  199448496                0
# 4  1000001     계동길  CS100005         제과점  165688274               24
#
#    연령대_20_매출_비율  점포수
# 0            15   16
# 1            33    1
# 2             8    2
# 3            28    3
# 4            11    4

# %% [markdown]
# ### 32개 있는 데이터만 고르기

# %%
food = food[food['점포수'] != 0]

# %%
food_count=food.pivot_table(index=['상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명'],aggfunc='size')
food_count=pd.DataFrame(food_count[food_count == 32]).reset_index()
code=zip(food_count['상권_코드'],food_count['서비스_업종_코드'])
food_temp = food[food[['상권_코드','서비스_업종_코드']].apply(tuple,1).isin(code)]
food_temp_count=food_temp.pivot_table(index=['상권_코드', '상권_코드_명', '서비스_업종_코드', '서비스_업종_코드_명'],aggfunc='size')
sum(food_temp_count != 32)
# Out:
# 0

# %%
food_temp['상권_구분_코드_명']
# Out:
# 0          골목상권
# 3          골목상권
# 5          골목상권
# 6          골목상권
# 7          골목상권
#            ...
# 1218631    전통시장
# 1218632    전통시장
# 1218633    전통시장
# 1218634    전통시장
# 1218635    전통시장
# Name: 상권_구분_코드_명, Length: 228128, dtype: object

# %%
# 일단 뺀거 저장하기
golmok=food[food['상권_구분_코드_명']=='골목상권']
golmok.to_csv('./Data/golmok.csv',index=False)

# %%
golmok.sort_values(by=['기준_년_코드','기준_분기_코드'],inplace=True)

# %% [markdown]
# ### 서비스 업종별로의 분포 보기

# %%
plt.style.use('ggplot')

for service in golmok['서비스_업종_코드_명'].unique():
    test=golmok[golmok['서비스_업종_코드_명'] == service]
    test.sort_values(by=['기준_년_코드','기준_분기_코드'],inplace=True)
    test.reset_index(inplace=True,drop=True)
    test.reset_index(inplace=True)

    sns.lmplot(
		x='index',
		y='분기당_매출_금액',
        data=test,
        fit_reg=False, # 회귀선 안나오게
        scatter_kws={'s':100}, # 좌표상의 점의 크기
        hue='시군구명'
    )

    plt.title(f'{service} 매출액 분포')

    plt.show()

# %% [markdown]
# ### 추정치라 못믿겠어서 위아래 10%씩 자르고 해보기

# %%
from module.outlier import removeTen , thirtyTwo

golmok_test=removeTen(golmok,'분기당_매출_금액',10)
golmok_test=thirtyTwo(golmok_test)

# %%
plt.style.use('ggplot')

for service in golmok_test['서비스_업종_코드_명'].unique():
    test=golmok_test[golmok_test['서비스_업종_코드_명'] == service]
    test.sort_values(by=['기준_년_코드','기준_분기_코드'],inplace=True)
    test.reset_index(inplace=True,drop=True)
    test.reset_index(inplace=True)

    sns.lmplot(
		x='index',
		y='분기당_매출_금액',
        data=test,
        fit_reg=False, # 회귀선 안나오게
        scatter_kws={'s':100}, # 좌표상의 점의 크기
        hue='시군구명'
    )

    plt.title(f'{service} 매출액 분포')

    plt.show()

# %%
table=golmok.pivot_table(index=['시군구명'],columns=['서비스_업종_코드_명'],aggfunc='size')
sns.heatmap(
	table.T,
	fmt='d',
	cmap='YlGnBu',
	linewidth=2,
	cbar=True
)

plt.show()

# %%
table.apply((np.std,np.mean),axis=1).sort_values(by='mean',ascending=False)
# Out:
#              std    mean
# 시군구명
# 관악구   512.273321  1208.8
# 강남구   295.570710  1202.6
# 강서구   482.891764  1095.7
# 마포구   287.534732  1077.0
# 성북구   434.624538  1016.4
# 강동구   364.165423   983.3
# 동대문구  418.181035   941.6
# 은평구   393.035820   917.4
# 서초구   254.003937   908.0
# 구로구   404.278631   887.9
# 영등포구  427.215584   875.6
# 양천구   359.691226   875.0
# 동작구   359.084159   858.9
# 광진구   329.734590   839.3
# 성동구   279.880232   792.5
# 용산구   266.691166   782.2
# 중랑구   373.914785   746.4
# 송파구   184.805153   680.5
# 강북구   346.490917   628.2
# 금천구   308.449456   552.2
# 도봉구   223.351865   535.5
# 종로구   181.490771   523.7
# 서대문구  152.222826   471.3
# 중구    171.501992   404.4
# 노원구    75.342256   266.7

# %% [markdown]
# ### 역시나 구별로 봐도 데이터의 분포가 다르다. 그렇기 때문에 데이터 수가 많고 ,업종별로 고르게 데이터가 있는 강남구 아니면 마포구 둘중 강남구를 선택하겠다.
