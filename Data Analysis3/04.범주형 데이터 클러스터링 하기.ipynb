# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform
import warnings

# seaborn 사용하기
import seaborn as sns

plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic') # os가 macos
elif platform.system() == 'Windows':
    path = 'c:/Windows/Fonts/malgun.ttf' # os가 windows
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print("Unknown System")

warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./Data/second_target.csv')

# %%
target=data.iloc[:,:13]
target.head()
# Out:
#    기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명  시군구코드 시군구명    행정동_코드 행정동_코드_명  \
# 0     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 1     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 2     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 3     2021         1        A       골목상권  11110  종로구  11110600      가회동
# 4     2021         1        A       골목상권  11110  종로구  11110600      가회동
#
#      상권_코드 상권_코드_명 서비스_업종_코드 서비스_업종_코드_명  분기당_매출_금액
# 0  1000001     계동길  CS100001       한식음식점  316763168
# 1  1000001     계동길  CS100002       중식음식점   39791852
# 2  1000001     계동길  CS100003       일식음식점   60325474
# 3  1000001     계동길  CS100004       양식음식점  199448496
# 4  1000001     계동길  CS100005         제과점  165688274

# %%
feature=data[['시간대_06~11_매출_비율','연령대_20_매출_비율','점포수']]
feature.head()
# Out:
#    시간대_06~11_매출_비율  연령대_20_매출_비율  점포수
# 0                2            15   16
# 1                0            33    1
# 2                0             8    2
# 3                0            28    3
# 4               24            11    4

# %% [markdown]
# ### 범주형 데이터 클러스터링 하기 위해서 공통점이 있는지 그래프 그려보기
# - 상권 구분 <br><br>
# - 구별 <br><br>
# - 동별 <br><br>
#
# - 상권 구분 + 업종 <br><br>
# - 구 + 업종 <br><br>
# - 동 + 업종 <br><br>
# -
